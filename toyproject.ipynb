# %% [markdown]
# <a href="https://colab.research.google.com/github/saurabhkr78/Learning/blob/main/toyproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df=pd.read_csv("/content/placement.csv")

# %% [markdown]
# **Pre-Processing**

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   cgpa       100 non-null    float64
#  1   iq         100 non-null    float64
#  2   placement  100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
df=df.iloc[:,1:]#all rows but column from 1st index

# %%
df.head()
# Out:
#    cgpa     iq  placement
# 0   6.8  123.0          1
# 1   5.9  106.0          0
# 2   5.3  121.0          0
# 3   7.4  132.0          1
# 4   5.8  142.0          0

# %%
'''
#pre-process+EDA+feature selection
#extract i/o and o/p cols
#scale the values
#train test split
# train the model
#evaluate the mode/model selection
#deploy the model



'''

# %% [markdown]
# **EDA**

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'],df['iq'],c=df['placement'])

# %% [markdown]
# if our data is having linear behaviour we gonna use logistic regression as it divide it into two classes

# %%
x=df.iloc[:,0:2]
y=df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
x.shape
# Out:
# (100, 2)

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
y.shape
# Out:
# (100,)

# %% [markdown]
# Train test Split

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.1)

# %%
x_train
# Out:
#     cgpa     iq
# 30   7.6  128.0
# 96   4.4   42.0
# 45   6.0   66.0
# 0    6.8  123.0
# 7    5.0   63.0
# ..   ...    ...
# 35   6.8   90.0
# 10   6.0   45.0
# 2    5.3  121.0
# 26   7.0  199.0
# 52   7.0  175.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 30    1
# 96    0
# 45    1
# 0     1
# 7     0
#      ..
# 35    1
# 10    1
# 2     0
# 26    1
# 52    1
# Name: placement, Length: 90, dtype: int64

# %%
x_test
# Out:
#     cgpa     iq
# 31   3.9  109.0
# 13   6.4  116.0
# 1    5.9  106.0
# 58   8.0   79.0
# 54   6.4  141.0
# 24   4.7  121.0
# 43   6.8  141.0
# 57   6.5  130.0
# 27   6.0  124.0
# 40   4.9  134.0

# %%
y_test
# Out:
# 31    0
# 13    1
# 1     0
# 58    1
# 54    1
# 24    0
# 43    1
# 57    1
# 27    1
# 40    0
# Name: placement, dtype: int64

# %% [markdown]
# Scaling

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler=StandardScaler()

# %%
x_train=scaler.fit_transform(x_train)

# %%
x_train
# Out:
# array([[ 1.40744217,  0.0973105 ],
#        [-1.39964471, -1.97757452],
#        [ 0.00389873, -1.39853684],
#        [ 0.70567045, -0.02332235],
#        [-0.87331592, -1.47091655],
#        [-0.25926566,  0.19381678],
#        [ 0.0916202 ,  0.19381678],
#        [ 1.31972071,  0.8211076 ],
#        [-2.18913789,  2.63060034],
#        [ 2.02149242,  1.0623733 ],
#        [-1.04875885, -0.28871462],
#        [-1.13648031, -0.89187887],
#        [ 0.79339192,  0.36270277],
#        [-0.96103738,  0.65222161],
#        [-0.52243006, -0.24046148],
#        [-1.13648031, -1.73630882],
#        [-0.87331592, -0.79537259],
#        [ 1.5828851 , -0.24046148],
#        [-0.78559445,  1.25538586],
#        [-1.48736617,  1.83442353],
#        [ 0.79339192, -0.67473974],
#        [-0.96103738,  0.74872789],
#        [ 0.0916202 , -1.03663829],
#        [-0.52243006,  0.26619649],
#        [-2.36458082,  1.42427185],
#        [ 0.00389873,  0.60396847],
#        [ 0.61794899,  0.72460132],
# ...

# %%
x_test=scaler.transform(x_test)

# %%
x_test
# Out:
# array([[-1.83825203e+00, -3.61094330e-01],
#        [ 3.54784591e-01, -1.92208340e-01],
#        [-8.38227331e-02, -4.33474040e-01],
#        [ 1.75832803e+00, -1.08489143e+00],
#        [ 3.54784591e-01,  4.10955908e-01],
#        [-1.13648031e+00, -7.15754908e-02],
#        [ 7.05670451e-01,  4.10955908e-01],
#        [ 4.42506056e-01,  1.45563639e-01],
#        [ 3.89873177e-03,  8.04218998e-04],
#        [-9.61037382e-01,  2.42069918e-01]])

# %% [markdown]
# model training

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
#model training
clf.fit(x_train,y_train)
# Out:
# LogisticRegression()
# LogisticRegression()

# %%
y_pred=clf.predict(x_test)

# %%
y_test
# Out:
# 31    0
# 13    1
# 1     0
# 58    1
# 54    1
# 24    0
# 43    1
# 57    1
# 27    1
# 40    0
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(x_train,y_train.values,clf=clf,legend=2)
# Out:
# <Axes: >

# %%
import pickle #convert obj into file

# %%
pickle.dump(clf,open('model.pkl','wb'))
